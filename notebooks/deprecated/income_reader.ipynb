# %%
import pandas as pd

# %% [markdown]
# ## Lade Daten

# %%
df_raw = pd.read_csv("82411-01-03-4.csv", encoding="ISO-8859-1", skiprows = 6, delimiter = ";")

# %%
# clean data

df_raw = df_raw.rename(columns = {"Unnamed: 0" : "year", "Unnamed: 1" : "kreis_key", "Unnamed: 2" : "kreis_name", "Tsd. EUR" : "income", "EUR" : "income_pp"})
df_raw = df_raw.dropna(subset = ["kreis_key"])
df_raw = df_raw[df_raw.kreis_key != "DG"]
df_raw.kreis_key.replace({"02": "02000", "11" : "11000"}, inplace=True) # Berlin, Hamburg

df_raw.head()
# Out:
#    year kreis_key                                      kreis_name    income  \
# 1  2018        01                              Schleswig-Holstein  66062082
# 2  2018     01001                     Flensburg, kreisfreie Stadt   1671015
# 3  2018     01002        Kiel, Landeshauptstadt, kreisfreie Stadt   4804347
# 4  2018     01003            Lübeck, Hansestadt, kreisfreie Stadt   4361215
# 5  2018     01004                    Neumünster, kreisfreie Stadt   1570313
#
#   income_pp
# 1     22833
# 2     18773
# 3     19392
# 4     20120
# 5     19775

# %%
# Pivot Data
df_piv = df_raw.pivot(index = "kreis_key", columns = "year", values = ["income_pp", "income"])

df_piv.columns  =[f"{s1}_{s2}" for (s1,s2) in df_piv.columns.tolist()]

df_piv.reset_index(inplace= True)

# %%
df_piv.head()
# Out:
#   kreis_key income_pp_2000 income_pp_2001 income_pp_2002 income_pp_2003  \
# 0        01          15783          16396          16363          16907
# 1     01001          14763          15144          15177          15499
# 2     01002          14348          14833          14909          15295
# 3     01003          14467          14977          15191          15890
# 4     01004          14766          15487          15216          15324
#
#   income_pp_2004 income_pp_2005 income_pp_2006 income_pp_2007 income_pp_2008  \
# 0          17088          17523          17740          18121          18489
# 1          15453          16215          16827          17521          17409
# 2          15354          15770          15940          16322          16563
# 3          16157          16538          16697          16921          17042
# 4          15032          15438          15697          16022          16142
#
#    ... income_2009 income_2010 income_2011 income_2012 income_2013  \
# 0  ...    52270914    52871001    54661343    56434510    57311389
# 1  ...     1430461     1418785     1448058     1493399     1505825
# 2  ...     3903615     3939614     4034330     4158259     4310035
# 3  ...     3587403     3577055     3652388     3764155     3808498
# 4  ...     1253945     1248038     1274049     1313171     1340109
#
#   income_2014 income_2015 income_2016 income_2017 income_2018
# 0    58584166    60606797    62480036    64350736    66062082
# 1     1518602     1557509     1571451     1627397     1671015
# 2     4283943     4434181     4559584     4692052     4804347
# 3     3885301     4093123     4139659     4256285     4361215
# 4     1388380     1420594     1493064     1532486     1570313
#
# [5 rows x 39 columns]

# %%
# drop rows that are not on "Kreis"-level

df = df_piv[[len(i) == 5 for i in df_piv.kreis_key]]

# %%
df.head()
# Out:
#   kreis_key income_pp_2000 income_pp_2001 income_pp_2002 income_pp_2003  \
# 1     01001          14763          15144          15177          15499
# 2     01002          14348          14833          14909          15295
# 3     01003          14467          14977          15191          15890
# 4     01004          14766          15487          15216          15324
# 5     01051          14038          14651          14687          15283
#
#   income_pp_2004 income_pp_2005 income_pp_2006 income_pp_2007 income_pp_2008  \
# 1          15453          16215          16827          17521          17409
# 2          15354          15770          15940          16322          16563
# 3          16157          16538          16697          16921          17042
# 4          15032          15438          15697          16022          16142
# 5          15777          16071          16290          16738          17251
#
#    ... income_2009 income_2010 income_2011 income_2012 income_2013  \
# 1  ...     1430461     1418785     1448058     1493399     1505825
# 2  ...     3903615     3939614     4034330     4158259     4310035
# 3  ...     3587403     3577055     3652388     3764155     3808498
# 4  ...     1253945     1248038     1274049     1313171     1340109
# 5  ...     2332173     2368402     2456280     2523783     2586597
#
#   income_2014 income_2015 income_2016 income_2017 income_2018
# 1     1518602     1557509     1571451     1627397     1671015
# 2     4283943     4434181     4559584     4692052     4804347
# 3     3885301     4093123     4139659     4256285     4361215
# 4     1388380     1420594     1493064     1532486     1570313
# 5     2665499     2775558     2851506     2944465     2999606
#
# [5 rows x 39 columns]

# %%
# save to csv

df.to_csv("income.csv")
