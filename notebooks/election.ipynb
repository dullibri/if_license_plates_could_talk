# %%
import pandas as pd
import os

from if_license_plates_could_talk import data

# %% [markdown]
# ## Europawahl 2014 / 2019

# %%
election_path = os.path.join(data.utils.path_to_data_dir(), "raw", "election", "ew19_kerg.csv")
election = pd.read_csv(election_path, skiprows=[0, 1, 3, 4], delimiter=";")
election.dropna(axis=1, inplace=True, how="all")
election.columns = ["kreis_key",  "kreis_name","bl_key","ew_eli_2019", "ew_eli_2014", "ew_vot_2019", "ew_vot_2014", "ew_invalid_2019", "ew_invalid_2014", "ew_valid_2019", "ew_valid_2014"] + list(election.columns[11:])
election.drop("kreis_name", axis =1, inplace=True)
election.dropna(subset=["kreis_key"], inplace=True)

# %%
df_partei = pd.DataFrame()
new_columns = list(election.columns[:10])
partei_key = ""
for i in range(10, len(election.columns)):
    clm = election.columns[i]
    if "Unnamed: " not in clm:
        partei_key = clm.lower()
        replacements = {
            " " : "_",
            "/" : "_",
            "." : "_",
            "-" : "_",
            "ä" : "ae",
            "ö" : "oe",
            "ü" : "ue",
            "ß" : "ss"
        }
        for rep in replacements:
            partei_key = partei_key.replace(rep, replacements[rep])
        
        df_partei = df_partei.append({"partei_key" : partei_key, "partei_name" : clm}, ignore_index=True)
        
        new_columns.append(f"ew_vot_abs_{partei_key}_2019")
    else:
        new_columns.append(f"ew_vot_abs_{partei_key}_2014")

election.columns = new_columns

# %%
election = election[election.kreis_key > 99]

# %%
election.kreis_key = data.utils.fix_key(election.kreis_key)

# %%
election.head()
# Out:
#   kreis_key  bl_key  ew_eli_2019  ew_eli_2014  ew_vot_2019  ew_vot_2014  \
# 0     01001     1.0      70431.0      70929.0      39647.0      25350.0
# 1     01002     1.0     186195.0     188135.0     109595.0      75741.0
# 2     01003     1.0     166530.0     167198.0      90946.0      62933.0
# 3     01004     1.0      60215.0      60970.0      29036.0      27659.0
# 4     01051     1.0     107045.0     107804.0      58244.0      42819.0
#
#    ew_invalid_2019  ew_invalid_2014  ew_valid_2019  ew_valid_2014  ...  \
# 0            237.0            176.0        39410.0        25174.0  ...
# 1            577.0            405.0       109018.0        75336.0  ...
# 2            461.0            424.0        90485.0        62509.0  ...
# 3            231.0            409.0        28805.0        27250.0  ...
# 4            475.0            469.0        57769.0        42350.0  ...
#
#    ew_vot_abs_graue_panther_2019  \
# 0                           80.0
# 1                          243.0
# 2                          181.0
# 3                           80.0
# 4                          170.0
#
#    ew_vot_abs_lkr___bernd_lucke_und_die_liberal_konservativen_reformer_2019  \
# 0                                               28.0
# 1                                              110.0
# 2                                               73.0
# 3                                               70.0
# 4                                               45.0
#
#    ew_vot_abs_menschliche_welt___fuer_das_wohl_und_gluecklichsein_aller_2019  \
# 0                                               40.0
# 1                                               99.0
# 2                                               68.0
# 3                                               17.0
# 4                                               54.0
#
#    ew_vot_abs_neue_liberale_–_die_sozialliberalen_2019  \
# 0                                               24.0
# 1                                               62.0
# 2                                               54.0
# 3                                               14.0
# 4                                               23.0
#
#    ew_vot_abs_oekologische_linke_2019  ew_vot_abs_partei_der_humanisten_2019  \
# 0                                52.0                                   97.0
# 1                               198.0                                  371.0
# 2                                97.0                                  234.0
# 3                                20.0                                   56.0
# 4                                41.0                                   78.0
#
#    ew_vot_abs_partei_fuer_die_tiere_deutschland_2019  \
# 0                                               61.0
# 1                                              144.0
# 2                                              126.0
# 3                                               56.0
# 4                                              118.0
#
#    ew_vot_abs_partei_fuer_gesundheitsforschung_2019  \
# 0                                              47.0
# 1                                             129.0
# 2                                             104.0
# 3                                              34.0
# 4                                             111.0
#
#    ew_vot_abs_volt_deutschland_2019  ew_vot_abs_volt_deutschland_2014
# 0                             285.0                             160.0
# 1                            1139.0                             283.0
# 2                             935.0                             256.0
# 3                             114.0                             185.0
# 4                             185.0                             168.0
#
# [5 rows x 71 columns]

# %%
df_partei.head()
# Out:
#                                     partei_key  \
# 0  christlich_demokratische_union_deutschlands
# 1      sozialdemokratische_partei_deutschlands
# 2                      buendnis_90_die_gruenen
# 3                                    die_linke
# 4                 alternative_fuer_deutschland
#
#                                    partei_name
# 0  Christlich Demokratische Union Deutschlands
# 1      Sozialdemokratische Partei Deutschlands
# 2                        BÜNDNIS 90/DIE GRÜNEN
# 3                                    DIE LINKE
# 4                  Alternative für Deutschland

# %%
election.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401 entries, 0 to 430
# Data columns (total 71 columns):
#  #   Column                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                           --------------  -----
#  0   kreis_key                                                                                                        401 non-null    object
#  1   bl_key                                                                                                           401 non-null    float64
#  2   ew_eli_2019                                                                                                      401 non-null    float64
#  3   ew_eli_2014                                                                                                      401 non-null    float64
#  4   ew_vot_2019                                                                                                      401 non-null    float64
#  5   ew_vot_2014                                                                                                      401 non-null    float64
#  6   ew_invalid_2019                                                                                                  401 non-null    float64
#  7   ew_invalid_2014                                                                                                  401 non-null    float64
#  8   ew_valid_2019                                                                                                    401 non-null    float64
#  9   ew_valid_2014                                                                                                    401 non-null    float64
#  10  ew_vot_abs_christlich_demokratische_union_deutschlands_2019                                                      305 non-null    float64
#  11  ew_vot_abs_christlich_demokratische_union_deutschlands_2014                                                      305 non-null    float64
#  12  ew_vot_abs_sozialdemokratische_partei_deutschlands_2019                                                          401 non-null    float64
#  13  ew_vot_abs_sozialdemokratische_partei_deutschlands_2014                                                          401 non-null    float64
#  14  ew_vot_abs_buendnis_90_die_gruenen_2019                                                                          401 non-null    float64
#  15  ew_vot_abs_buendnis_90_die_gruenen_2014                                                                          401 non-null    float64
#  16  ew_vot_abs_die_linke_2019                                                                                        401 non-null    float64
#  17  ew_vot_abs_die_linke_2014                                                                                        401 non-null    float64
#  18  ew_vot_abs_alternative_fuer_deutschland_2019                                                                     401 non-null    float64
#  19  ew_vot_abs_alternative_fuer_deutschland_2014                                                                     401 non-null    float64
#  20  ew_vot_abs_christlich_soziale_union_in_bayern_e_v__2019                                                          96 non-null     float64
#  21  ew_vot_abs_christlich_soziale_union_in_bayern_e_v__2014                                                          96 non-null     float64
#  22  ew_vot_abs_freie_demokratische_partei_2019                                                                       401 non-null    float64
#  23  ew_vot_abs_freie_demokratische_partei_2014                                                                       401 non-null    float64
#  24  ew_vot_abs_freie_waehler_2019                                                                                    401 non-null    float64
#  25  ew_vot_abs_freie_waehler_2014                                                                                    401 non-null    float64
#  26  ew_vot_abs_piratenpartei_deutschland_2019                                                                        401 non-null    float64
#  27  ew_vot_abs_piratenpartei_deutschland_2014                                                                        401 non-null    float64
#  28  ew_vot_abs_partei_mensch_umwelt_tierschutz_2019                                                                  401 non-null    float64
#  29  ew_vot_abs_partei_mensch_umwelt_tierschutz_2014                                                                  401 non-null    float64
#  30  ew_vot_abs_nationaldemokratische_partei_deutschlands_2019                                                        401 non-null    float64
#  31  ew_vot_abs_nationaldemokratische_partei_deutschlands_2014                                                        401 non-null    float64
#  32  ew_vot_abs_familien_partei_deutschlands_2019                                                                     401 non-null    float64
#  33  ew_vot_abs_familien_partei_deutschlands_2014                                                                     401 non-null    float64
#  34  ew_vot_abs_oekologisch_demokratische_partei_2019                                                                 401 non-null    float64
#  35  ew_vot_abs_oekologisch_demokratische_partei_2014                                                                 401 non-null    float64
#  36  ew_vot_abs_partei_fuer_arbeit,_rechtsstaat,_tierschutz,_elitenfoerderung_und_basisdemokratische_initiative_2019  401 non-null    float64
#  37  ew_vot_abs_partei_fuer_arbeit,_rechtsstaat,_tierschutz,_elitenfoerderung_und_basisdemokratische_initiative_2014  401 non-null    float64
#  38  ew_vot_abs_ab_jetzt___demokratie_durch_volksabstimmung___politik_fuer_die_menschen_2019                          401 non-null    float64
#  39  ew_vot_abs_ab_jetzt___demokratie_durch_volksabstimmung___politik_fuer_die_menschen_2014                          401 non-null    float64
#  40  ew_vot_abs_bayernpartei_2019                                                                                     401 non-null    float64
#  41  ew_vot_abs_bayernpartei_2014                                                                                     401 non-null    float64
#  42  ew_vot_abs_deutsche_kommunistische_partei_2019                                                                   401 non-null    float64
#  43  ew_vot_abs_deutsche_kommunistische_partei_2014                                                                   401 non-null    float64
#  44  ew_vot_abs_marxistisch_leninistische_partei_deutschlands_2019                                                    401 non-null    float64
#  45  ew_vot_abs_marxistisch_leninistische_partei_deutschlands_2014                                                    400 non-null    float64
#  46  ew_vot_abs_sozialistische_gleichheitspartei,_vierte_internationale_2019                                          401 non-null    float64
#  47  ew_vot_abs_sozialistische_gleichheitspartei,_vierte_internationale_2014                                          398 non-null    float64
#  48  ew_vot_abs_aktion_partei_fuer_tierschutz_–_das_original_2019                                                     401 non-null    float64
#  49  ew_vot_abs_allianz_fuer_menschenrechte,_tier__und_naturschutz_2019                                               401 non-null    float64
#  50  ew_vot_abs_buendnis_c___christen_fuer_deutschland_2019                                                           401 non-null    float64
#  51  ew_vot_abs_buendnis_fuer_innovation_&_gerechtigkeit_2019                                                         401 non-null    float64
#  52  ew_vot_abs_buendnis_grundeinkommen___die_grundeinkommenspartei_2019                                              401 non-null    float64
#  53  ew_vot_abs_demokratie_direkt!_2019                                                                               401 non-null    float64
#  54  ew_vot_abs_demokratie_in_europa___diem25_2019                                                                    401 non-null    float64
#  55  ew_vot_abs_der_dritte_weg_2019                                                                                   401 non-null    float64
#  56  ew_vot_abs_die_grauen_–_fuer_alle_generationen_2019                                                              401 non-null    float64
#  57  ew_vot_abs_die_rechte_–_partei_fuer_volksabstimmung,_souveraenitaet_und_heimatschutz_2019                        401 non-null    float64
#  58  ew_vot_abs_die_violetten_2019                                                                                    401 non-null    float64
#  59  ew_vot_abs_europaeische_partei_liebe_2019                                                                        401 non-null    float64
#  60  ew_vot_abs_feministische_partei_die_frauen_2019                                                                  401 non-null    float64
#  61  ew_vot_abs_graue_panther_2019                                                                                    401 non-null    float64
#  62  ew_vot_abs_lkr___bernd_lucke_und_die_liberal_konservativen_reformer_2019                                         401 non-null    float64
#  63  ew_vot_abs_menschliche_welt___fuer_das_wohl_und_gluecklichsein_aller_2019                                        401 non-null    float64
#  64  ew_vot_abs_neue_liberale_–_die_sozialliberalen_2019                                                              401 non-null    float64
#  65  ew_vot_abs_oekologische_linke_2019                                                                               401 non-null    float64
#  66  ew_vot_abs_partei_der_humanisten_2019                                                                            401 non-null    float64
#  67  ew_vot_abs_partei_fuer_die_tiere_deutschland_2019                                                                401 non-null    float64
#  68  ew_vot_abs_partei_fuer_gesundheitsforschung_2019                                                                 401 non-null    float64
#  69  ew_vot_abs_volt_deutschland_2019                                                                                 401 non-null    float64
#  70  ew_vot_abs_volt_deutschland_2014                                                                                 401 non-null    float64
# dtypes: float64(70), object(1)
# memory usage: 225.6+ KB
