# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import random

plt.style.use("seaborn")

# %matplotlib inline

# %%
df_geo = gpd.read_file(os.path.join("shapefiles", "vg2500_geo84", "vg2500_krs.shp"))

# %%
df_geo.head()
# Out:
#    USE     RS        RS_ALT           GEN     SHAPE_LENG    SHAPE_AREA  \
# 0    4  01001  010010000000     Flensburg   32467.034276  5.324899e+07
# 1    4  01002  010020000000          Kiel   73027.302434  1.218654e+08
# 2    4  01003  010030000000        Lübeck  104861.094220  2.211386e+08
# 3    4  01004  010040000000    Neumünster   39858.818376  8.092363e+07
# 4    4  01051  010510000000  Dithmarschen  202206.675707  1.450311e+09
#
#                                             geometry
# 0  POLYGON ((9.48982 54.82296, 9.50467 54.81004, ...
# 1  POLYGON ((10.19057 54.38909, 10.18370 54.38910...
# 2  POLYGON ((10.89297 53.95695, 10.90337 53.95705...
# 3  POLYGON ((10.03454 54.12915, 10.02277 54.10938...
# 4  MULTIPOLYGON (((9.05176 54.36640, 9.07193 54.3...

# %%
df_geo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   USE         402 non-null    int64
#  1   RS          402 non-null    object
#  2   RS_ALT      402 non-null    object
#  3   GEN         402 non-null    object
#  4   SHAPE_LENG  402 non-null    float64
#  5   SHAPE_AREA  402 non-null    float64
#  6   geometry    402 non-null    geometry
#  7   rd          402 non-null    int64
# dtypes: float64(2), geometry(1), int64(2), object(3)
# memory usage: 25.2+ KB

# %%
df_2018 = pd.read_csv("../data/data_2018.csv", index_col = 0)

# %%
df_2018.head()
# Out:
#    kreis_key                                      kreis_name  income_pp_2018  \
# 0       1001                     Flensburg, kreisfreie Stadt           18773
# 1       1002        Kiel, Landeshauptstadt, kreisfreie Stadt           19392
# 2       1003            Lübeck, Hansestadt, kreisfreie Stadt           20120
# 3       1004                    Neumünster, kreisfreie Stadt           19775
# 4       1051                         Dithmarschen, Landkreis           22498
#
#    income_2018  crimes_2018  population_2018
# 0      1671015       8156.0            89012
# 1      4804347      24621.0           247746
# 2      4361215      22685.0           216758
# 3      1570313      10688.0            79411
# 4      2999606       7224.0           133329

# %%
plt.rcParams["figure.figsize"] = [16, 11]

# %%
df_geo = df_geo.assign(first_digits = lambda x: x['RS'].str.slice(start=0, stop=2))

# %%
fig, ax = plt.subplots()

df_geo.plot(
    ax=ax, 
    column='first_digits', 
    categorical=True,
    cmap='tab20',
    alpha=0.9
)

ax.set(
    title='Germany', 
    aspect=1.3, 
    facecolor='lightblue'
);
